# %% [markdown]
# # World Cup Model Training
#
# This notebook is a lightweight companion to `ml/train_model.py`. The production training pipeline lives in the script so the model outputs can be regenerated consistently from the command line.

# %%
# From the project root, run:
# python ml/train_model.py
